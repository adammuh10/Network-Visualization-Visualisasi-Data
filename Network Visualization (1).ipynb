# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
G = nx.Graph()

G.add_node('bekasi',role='bekasi')
G.add_node('bogor',role='bogor')
G.add_node('depok',role='depok')
G.add_node('sukabumi',role='sukabumi')
G.add_node('cianjur',role='cianjur')
G.add_node('karawang',role='karawang')
G.add_node('purwakarta',role='purwakarta')
G.add_node('subang',role='subang')
G.add_node('indramayu',role='indramayu')
G.add_node('cirebon',role='cirebon')
G.add_node('kuningan',role='kuningan')
G.add_node('majalengka',role='majalengka')
G.add_node('sumedang',role='sumedang')
G.add_node('bandung',role='bandung')
G.add_node('cimahi',role='cimahi')
G.add_node('garut',role='garut')
G.add_node('tasikmalaya',role='tasikmalaya')
G.add_node('ciamis',role='ciamis')

G.nodes(data=True)
# Out:
# NodeDataView({'bekasi': {'role': 'bekasi'}, 'bogor': {'role': 'bogor'}, 'depok': {'role': 'depok'}, 'sukabumi': {'role': 'sukabumi'}, 'cianjur': {'role': 'cianjur'}, 'karawang': {'role': 'karawang'}, 'purwakarta': {'role': 'purwakarta'}, 'subang': {'role': 'subang'}, 'indramayu': {'role': 'indramayu'}, 'cirebon': {'role': 'cirebon'}, 'kuningan': {'role': 'kuningan'}, 'majalengka': {'role': 'majalengka'}, 'sumedang': {'role': 'sumedang'}, 'bandung': {'role': 'bandung'}, 'cimahi': {'role': 'cimahi'}, 'garut': {'role': 'garut'}, 'tasikmalaya': {'role': 'tasikmalaya'}, 'ciamis': {'role': 'ciamis'}})

# %%
G.add_edge('bandung','cimahi',weight=50,relation='1')
G.add_edge('depok','bekasi',weight=7,relation='2')
G.add_edge('bogor','depok',weight=11,relation='3')
G.add_edge('bogor','cianjur',weight=10,relation='4')
G.add_edge('bogor','sukabumi',weight=9,relation='5')
G.add_edge('bekasi','karawang',weight=5,relation='6')
G.add_edge('purwakarta','karawang',weight=9,relation='7')
G.add_edge('purwakarta','subang',weight=17,relation='8')
G.add_edge('cianjur','sukabumi',weight=12,relation='9')
G.add_edge('bandung','cianjur',weight=15,relation='10')
G.add_edge('bandung','sumedang',weight=3,relation='11')
G.add_edge('majalengka','sumedang',weight=4,relation='12')
G.add_edge('ciamis','tasikmalaya',weight=15,relation='13')
G.add_edge('indramayu','cirebon',weight=18,relation='14')
G.add_edge('purwakarta','cimahi',weight=5,relation='15')
G.add_edge('kuningan','cirebon',weight=10,relation='16')
G.add_edge('garut','tasikmalaya',weight=8,relation='17')
G.add_edge('bandung','garut',weight=9,relation='18')
G.add_edge('majalengka','cirebon',weight=12,relation='19')
G.add_edge('subang','cirebon',weight=20,relation='20')
G.add_edge('purwakarta','indramayu',weight=40,relation='21')
G.add_edge('tasikmalaya','sumedang',weight=0,relation='22')

G.edges(data=True)
# Out:
# EdgeDataView([('bekasi', 'depok', {'weight': 7, 'relation': '2'}), ('bekasi', 'karawang', {'weight': 5, 'relation': '6'}), ('bogor', 'depok', {'weight': 11, 'relation': '3'}), ('bogor', 'cianjur', {'weight': 10, 'relation': '4'}), ('bogor', 'sukabumi', {'weight': 9, 'relation': '5'}), ('sukabumi', 'cianjur', {'weight': 12, 'relation': '9'}), ('cianjur', 'bandung', {'weight': 15, 'relation': '10'}), ('karawang', 'purwakarta', {'weight': 9, 'relation': '7'}), ('purwakarta', 'subang', {'weight': 17, 'relation': '8'}), ('purwakarta', 'cimahi', {'weight': 5, 'relation': '15'}), ('purwakarta', 'indramayu', {'weight': 40, 'relation': '21'}), ('subang', 'cirebon', {'weight': 20, 'relation': '20'}), ('indramayu', 'cirebon', {'weight': 18, 'relation': '14'}), ('cirebon', 'kuningan', {'weight': 10, 'relation': '16'}), ('cirebon', 'majalengka', {'weight': 12, 'relation': '19'}), ('majalengka', 'sumedang', {'weight': 4, 'relation': '12'}), ('sumedang', 'bandung', {'weight': 3, 'relation': '11'}),
# ...

# %%
nx.draw_networkx(G, with_labels=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
list(G.edges)
# Out:
# [('bekasi', 'depok'),
#  ('bekasi', 'karawang'),
#  ('bogor', 'depok'),
#  ('bogor', 'cianjur'),
#  ('bogor', 'sukabumi'),
#  ('sukabumi', 'cianjur'),
#  ('cianjur', 'bandung'),
#  ('karawang', 'purwakarta'),
#  ('purwakarta', 'subang'),
#  ('purwakarta', 'cimahi'),
#  ('purwakarta', 'indramayu'),
#  ('subang', 'cirebon'),
#  ('indramayu', 'cirebon'),
#  ('cirebon', 'kuningan'),
#  ('cirebon', 'majalengka'),
#  ('majalengka', 'sumedang'),
#  ('sumedang', 'bandung'),
#  ('sumedang', 'tasikmalaya'),
#  ('bandung', 'cimahi'),
#  ('bandung', 'garut'),
#  ('garut', 'tasikmalaya'),
#  ('tasikmalaya', 'ciamis')]

# %%
list(G.neighbors('purwakarta'))
# Out:
# ['karawang', 'subang', 'cimahi', 'indramayu']

# %%
nx.degree_centrality(G)
# Out:
# {'bekasi': 0.11764705882352941,
#  'bogor': 0.1764705882352941,
#  'depok': 0.11764705882352941,
#  'sukabumi': 0.11764705882352941,
#  'cianjur': 0.1764705882352941,
#  'karawang': 0.11764705882352941,
#  'purwakarta': 0.23529411764705882,
#  'subang': 0.11764705882352941,
#  'indramayu': 0.11764705882352941,
#  'cirebon': 0.23529411764705882,
#  'kuningan': 0.058823529411764705,
#  'majalengka': 0.11764705882352941,
#  'sumedang': 0.1764705882352941,
#  'bandung': 0.23529411764705882,
#  'cimahi': 0.11764705882352941,
#  'garut': 0.11764705882352941,
#  'tasikmalaya': 0.1764705882352941,
#  'ciamis': 0.058823529411764705}

# %%
nx.betweenness_centrality(G)
# Out:
# {'bekasi': 0.07720588235294118,
#  'bogor': 0.10661764705882353,
#  'depok': 0.06985294117647059,
#  'sukabumi': 0.0,
#  'cianjur': 0.23161764705882354,
#  'karawang': 0.1213235294117647,
#  'purwakarta': 0.2867647058823529,
#  'subang': 0.04779411764705882,
#  'indramayu': 0.04779411764705882,
#  'cirebon': 0.20220588235294118,
#  'kuningan': 0.0,
#  'majalengka': 0.16176470588235295,
#  'sumedang': 0.2647058823529412,
#  'bandung': 0.4301470588235294,
#  'cimahi': 0.1801470588235294,
#  'garut': 0.0661764705882353,
#  'tasikmalaya': 0.1323529411764706,
#  'ciamis': 0.0}

# %% [markdown]
# # Kesimpulan
# - Dari Graph diatas dapat disimpulkan bahwa Kota Purwakarta, Kota Cirebon dan Kota Bandung memiliki nilai degree centrality tertinggi dengan nilai 0.23529411764705882.
# - Lalu untuk nilai betweenness centrality tertinggi juga diraih oleh kota Purwakarta, Cirebon dan Bandung dengan nilai 0.4301470588235294.
# - Sehingga dapat disimpulkan bahwa kota purwakarta, cirebon dan bandung merupakan kota terpenting di jawa barat
#
#
# - ADAM MUHAMMAD IRSYAD RIFAT
# - 1301174260
